# %% [markdown]
# <a href="https://colab.research.google.com/github/mypage-shivangi/Sea-Level-Predictor/blob/main/Sea_Level_Predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/mypage-shivangi/Sea-Level-Predictor
# Out:
# Cloning into 'Sea-Level-Predictor'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 10 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (10/10), 7.67 KiB | 7.67 MiB/s, done.

# %%
# %cd Sea-Level-Predictor
# Out:
# /content/Sea-Level-Predictor

# %%
# !ls
# Out:
# epa-sea-level.csv  README.md	     sea_level_predictor.py
# main.py		   requirements.txt  test_module.py

# %%
# !python main.py
# Out:
# ....
# ----------------------------------------------------------------------
# Ran 4 tests in 0.690s
#
# OK

# %%
import sea_level_predictor as slp
import matplotlib.pyplot as plt

fig = slp.draw_plot()
plt.show()
